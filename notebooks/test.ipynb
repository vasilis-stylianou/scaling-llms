# %%
# %load_ext autoreload
# %autoreload 2

from scaling_llms.data import DataManager, DATA_SOURCES

# %%
data_mgr = DataManager()

# %%
data_mgr.list_data_sources()
# Out:
# ['tiny_shakespeare', 'wikitext103', 'openwebtext']

# %%
train_iter, val_iter = data_mgr.get_loaders(
    source=DATA_SOURCES.tiny_shakespeare,
    seq_len=128,
    batch_size=32,
    num_workers=2,
    val_frac=0.1,
)
# Out:
# `trust_remote_code` is not supported anymore.
# Please check that the Hugging Face dataset 'tiny_shakespeare' isn't based on a loading script and remove `trust_remote_code`.
# If the dataset is based on a loading script, please ask the dataset author to remove it and convert it to a standard format like Parquet.
# ...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 train_iter, val_iter = data_mgr.get_loaders(
#       2     source=DATA_SOURCES.tiny_shakespeare,
#       3     seq_len=128,
#       4     batch_size=32,
#       5     num_workers=2,
#       6     val_frac=0.1,
#       7 )
#
# File ~/Desktop/scaling-llms/src/scaling_llms/data.py:229, in DataManager.get_loaders(self, source, seq_len, batch_size, val_frac, num_workers, pin_memory, persistent_workers, as_iterable, resume_step, seed, max_samples, val_split)
# ...
